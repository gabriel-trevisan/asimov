# %% [markdown]
# # LangSmith

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template("Fale uma curiosidade sobre o assunto: {assunto}")
chain_curiosidade = prompt | ChatOpenAI() | StrOutputParser()

# %%
prompt = ChatPromptTemplate.from_template("Crie uma história sobre o seguinte fato curioso: {assunto}")
chain_historia = prompt | ChatOpenAI() | StrOutputParser()

# %%
chain = chain_curiosidade | chain_historia

chain.invoke({'assunto':'gatinhos'})
# Out:
# 'Em uma pequena cidade do interior, vivia um gato chamado Tobias. Tobias era conhecido por sua curiosidade e agilidade, sempre explorando os cantos da cidade em busca de aventuras. Um dia, enquanto caminhava pela rua, ele ouviu um som estranho vindo de um beco escuro.\n\nCurioso, Tobias virou suas orelhas para o lado e começou a girá-las lentamente, tentando captar de onde vinha o som. Ele conseguiu identificar que era um miado de um gatinho assustado, preso em um buraco entre duas paredes.\n\nSem hesitar, Tobias correu em direção ao buraco e começou a miar para o gatinho, tentando acalmá-lo. Com suas orelhas girando em todas as direções, ele conseguia ouvir os movimentos do gatinho preso e percebeu que ele estava com fome e sede.\n\nCom toda sua agilidade, Tobias conseguiu encontrar uma forma de entrar no buraco e resgatar o gatinho. Com muito esforço e paciência, ele conseguiu levar o pequeno gato de volta para a segurança da rua.\n\nOs moradores da cidade ficaram impressionados com a habilidade de Tobias em captar sons e ajudar o gatinho em perigo. A partir desse dia, Tobias se tornou conhecido como o herói de orelhas mágicas, pois todos sabiam que suas orelhas incríveis o ajudaram a salvar um companheiro felino.\n\nDesde então, Tobias continuou explorando a cidade, sempre atento aos sons ao seu redor, pronto para ajudar quem precisasse. Sua capacidade única de girar as orelhas em 180 graus o tornou uma lenda entre os gatos da cidade, mostrando que, às vezes, as habilidades mais simples podem fazer a diferença.'

# %% [markdown]
# ![image.png](attachment:image.png)
